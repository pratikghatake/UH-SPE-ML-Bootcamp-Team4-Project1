# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib notebook

# %%
df19r = pd.read_csv('2019r.csv')
df18r = pd.read_csv('2018r.csv')
df17r = pd.read_csv('2017r.csv')
df16r = pd.read_csv('2016r.csv')
df15r = pd.read_csv('2015r.csv')

# %%
df15r['Year']=pd.Series(2015 for x in range(len(df15r.index)))

# %% [raw]
# df19r

# %%
result = pd.concat([df19r,df18r,df17r,df16r,df15r], ignore_index = True)

# %%
plt.scatter(result['GDP'], result['Score'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
result['Region']
# Out:
# 0                       Western Europe
# 1                       Western Europe
# 2                       Western Europe
# 3                       Western Europe
# 4                       Western Europe
#                     ...
# 777                 Sub-Saharan Africa
# 778                 Sub-Saharan Africa
# 779    Middle East and Northern Africa
# 780                 Sub-Saharan Africa
# 781                 Sub-Saharan Africa
# Name: Region, Length: 782, dtype: object

# %%
result.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-ee693b1b39fa> in <module>
# ----> 1 result.keys()
#
# NameError: name 'result' is not defined

# %%
df18r.keys()
